# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
os.listdir()
# Out:
# ['data.xlsx', 'dev.ipynb']

# %%
data = pd.read_excel('data.xlsx',sheet_name="傳金電")
data_vix = pd.read_excel('data.xlsx',sheet_name="vix")
data3= pd.read_excel('data.xlsx',sheet_name="data")
data4= pd.read_excel('data.xlsx',sheet_name="現貨")

# %%
import pandas as pd

# 1. 定義標題：手動提取或根據你的資料結構選取
# 根據你提供的資料，正確的欄位名稱應該從 "日期" 開始
column_names = [
    '日期', '加權指數:收盤價', '加權報酬指數:收盤價', '電子類:收盤價', 
    '金融保險:收盤價', '不含金融電子:收盤價', 'OTC指數:收盤價', 
    '不含金融電子報酬指數:收盤價', '電子類報酬指數:收盤價', '金融保險類報酬指數:收盤價', 
    '電子類:成交值比重(%)', '電子類:市值比重(%)'
]

# 2. 定位數據起始點
# 觀察資料，真正的數據大約從索引 3973 左右（或是從包含 "2010-01-04" 那列開始）
# 我們假設數據是從包含日期的那一行開始，並過濾掉不必要的 NaN
# 這裡使用 iloc 切掉前面的參數描述區 (假設 row 0-11 是參數)
clean_df = data.iloc[12:].copy()

# 3. 移除全空或多餘的索引欄位 (假設第一欄是無意義的 index)
# 使用 iloc 選取從「日期」欄位開始到最後的內容
clean_df = clean_df.iloc[:, 1:-1] 
clean_df.columns = column_names

# 4. 資料格式轉換與清理
# 將日期轉為 datetime 格式
clean_df['日期'] = pd.to_datetime(clean_df['日期'])


# 5. 重設索引
clean_df = clean_df.reset_index(drop=True)

# 顯示最後幾列確認結果
print(clean_df.tail())
# Out:
#              日期  加權指數:收盤價 加權報酬指數:收盤價  電子類:收盤價 金融保險:收盤價 不含金融電子:收盤價 OTC指數:收盤價  \
# 3961 2026-03-18  34348.58   78311.56  2139.08   2451.8   14170.62     329.4
# 3962 2026-03-19  33689.68    76819.8  2095.85  2413.35   13958.73    329.79
# 3963 2026-03-20  33543.88   76490.31  2085.73   2423.6   13865.21     328.4
# 3964 2026-03-23   32722.5   74617.31  2033.49  2387.18   13489.41    317.02
# 3965 2026-03-24  32612.24   74366.25   2023.2  2404.54    13493.1    312.74
#
#      不含金融電子報酬指數:收盤價 電子類報酬指數:收盤價 金融保險類報酬指數:收盤價 電子類:成交值比重(%) 電子類:市值比重(%)
# 3961       33816.88     4379.28       4710.54        83.31      79.347
# 3962       33312.13     4291.49       4636.67       80.343      79.253
# 3963        33096.9     4270.82       4656.36       81.583      79.208
# 3964       32199.85     4163.84       4586.39        71.94       79.16
# 3965       32209.94     4142.78       4619.73       79.261      79.022

# %%
data_vix
# Out:
#      格式：一般總覽/進階/指定/20061218-/遞增/日台指選擇權波動率指數(收盤價)/日期/日/  \
# 0                                             基準日:最近一日
# 1                                               更新標題:是
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 4730                                               NaN
# 4731                                               NaN
# 4732                                               NaN
# 4733                                               NaN
# 4734                                               NaN
#
#      表格欄位/代號種類^=^Z^;^週期編號^=^D^;^AllCMenuIDs^=^M216^;^是否轉置^=^False^;^檢視方式^=^7^;^AllFields^=^收盤價^;^MainTable^=^M216^;^ListType^=^日期^;^SelectDate^=^20061218-^;^SelectCMenuID^=^M216^;^SelectDate種類^=^3^;^AllFieldsNO^=^^;^自訂欄位公式^=^^;^自訂欄位Where條件^=^^;^多期數值處理方式^=^^;^多欄指定個股方式^=^1^;^多欄指定個股^=^VIX15^;^多欄指定群組名稱^=^^;^欄位顯示狀態^=^1^;^欄位轉換日期方式^=^日^;^欄位排序方式^=^^;^欄位採用各期最新^=^^;^樣本表系統定義全部代號^=^^;^單項目比較欄位^=^^;^單項目比較欄位編號^=^^;^表格類型^=^  \
# 0                                                 資料日期/
# 1                                                  參考標題
# 2                                                   NaN
# 3                                                    日期
# 4                                   2006-12-18 00:00:00
# ...                                                 ...
# 4730                                2026-03-18 00:00:00
# 4731                                2026-03-19 00:00:00
# 4732                                2026-03-20 00:00:00
# 4733                                2026-03-23 00:00:00
# 4734                                2026-03-24 00:00:00
#
#      日台指選擇權波動率指數(收盤價).收盤價/個股/VIX15//
# 0                                NaN
# 1           VIX15台指選擇權波動率指數(新5D):收盤價
# 2                                NaN
# 3           VIX15台指選擇權波動率指數(新5D):收盤價
# 4                              17.12
# ...                              ...
# 4730                           31.81
# 4731                            35.7
# 4732                           34.83
# 4733                           39.23
# 4734                           38.46
#
# [4735 rows x 3 columns]

# %%
columns = ['日期', 'VIX_收盤價']

data_vix_clean = data_vix.iloc[4:, 1:3].copy()
data_vix_clean.columns = columns
data_vix_clean['日期'] = pd.to_datetime(data_vix_clean['日期'])
data_vix_clean = data_vix_clean.reset_index(drop=True)

# %%
import pandas as pd

# 1. 根據你提供的圖片，手動整理出完整的欄位清單
# 這裡務必確保數量與 data3.iloc[:, 2:] 剩下來的欄位數量一致
full_columns = [
    "日期", "TWA00加權指數:收盤價", "TX台指期近期:收盤價", "TX2台指期次月:收盤價",
    "TX近期:交割月份", "TX近期:未沖銷契約數", "TX2次月:未沖銷契約數", "TWX摩根現貨:收盤價",
    "SMTF:收盤價", "SMTF2:收盤價", "SMTF:交割月份", "SMTF:未沖銷契約數", "SMTF2:未沖銷契約數",
    "TXOC台指選近月:全部未沖銷", "TXOC1台指選近月:全部未沖銷", "TXOC2台指選近月:全部未沖銷",
    "TXOP台指選近月:全部未沖銷", "TXOP1台指選近月:全部未沖銷", "TXOP2台指選近月:全部未沖銷",
    "TX03外資:期貨多方未平倉", "TX03外資:期貨空方未平倉", 
    "MTX01自營商:多方未平倉", "MTX02投信:多方未平倉", "MTX03外資:多方未平倉",
    "MTX01自營商:空方未平倉", "MTX02投信:空方未平倉", "MTX03外資:空方未平倉",
    "MTX近期:未沖銷契約數", "MTX2次月:未沖銷契約數",
    "TX近月:前十大淨", "TX全月:前十大淨", "TX近月:特定人淨", "TX全月:特定人淨",
    "TX03PM外資(盤後):多方交易", "TX03PM外資(盤後):空方交易", "TX03PM外資(盤後):淨額"
]

# 2. 用 iloc 切割：跳過前面那些系統參數列
# 根據你的資料，數據大約是從 index 4 開始，並且跳過前兩欄無用的 NaN
clean_data3 = data3.iloc[4:, 1:].copy()

# 3. 檢查欄位數量是否匹配（如果不匹配會報錯，可用來除錯）
if clean_data3.shape[1] == len(full_columns):
    clean_data3.columns = full_columns
else:
    print(f"警告：欄位數量不符！DataFrame 有 {clean_data3.shape[1]} 欄，但設定的標題有 {len(full_columns)} 個。")
    # 如果不符，我們先強制給個臨時標題，讓你可以繼續跑
    clean_data3.columns = [f"col_{i}" for i in range(clean_data3.shape[1])]

# 4. 資料型態轉換
# 轉日期
clean_data3['日期'] = pd.to_datetime(clean_data3['日期'])

# 轉數字：把所有收盤價、口數都轉成 float/int，非數字的轉 NaN
cols_to_convert = clean_data3.columns[1:]
clean_data3[cols_to_convert] = clean_data3[cols_to_convert].apply(pd.to_numeric, errors='coerce')

# 5. 整理收尾
clean_data3 = clean_data3.dropna(subset=['日期']).reset_index(drop=True)

print("清理後的 data3 摘要：")
print(clean_data3.info())
print(clean_data3.tail())
# Out:
# 清理後的 data3 摘要：
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5464 entries, 0 to 5463
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   日期                 5464 non-null   datetime64[ns]
#  1   TWA00加權指數:收盤價      5464 non-null   float64
#  2   TX台指期近期:收盤價        5464 non-null   int64
#  3   TX2台指期次月:收盤價       5464 non-null   int64
#  4   TX近期:交割月份          5464 non-null   int64
#  5   TX近期:未沖銷契約數        5464 non-null   int64
#  6   TX2次月:未沖銷契約數       5464 non-null   int64
#  7   TWX摩根現貨:收盤價        5455 non-null   float64
#  8   SMTF:收盤價           4149 non-null   float64
#  9   SMTF2:收盤價          3662 non-null   float64
#  10  SMTF:交割月份          4150 non-null   float64
#  11  SMTF:未沖銷契約數        4149 non-null   float64
#  12  SMTF2:未沖銷契約數       3666 non-null   float64
#  13  TXOC台指選近月:全部未沖銷    5342 non-null   float64
#  14  TXOC1台指選近月:全部未沖銷   5342 non-null   float64
#  15  TXOC2台指選近月:全部未沖銷   2677 non-null   float64
#  16  TXOP台指選近月:全部未沖銷    5342 non-null   float64
#  17  TXOP1台指選近月:全部未沖銷   5342 non-null   float64
#  18  TXOP2台指選近月:全部未沖銷   2677 non-null   float64
#  19  TX03外資:期貨多方未平倉     4600 non-null   float64
#  20  TX03外資:期貨空方未平倉     4600 non-null   float64
#  21  MTX01自營商:多方未平倉     4600 non-null   float64
#  22  MTX02投信:多方未平倉      4600 non-null   float64
#  23  MTX03外資:多方未平倉      4600 non-null   float64
#  24  MTX01自營商:空方未平倉     4600 non-null   float64
#  25  MTX02投信:空方未平倉      4600 non-null   float64
#  26  MTX03外資:空方未平倉      4600 non-null   float64
#  27  MTX近期:未沖銷契約數       5464 non-null   int64
#  28  MTX2次月:未沖銷契約數      5464 non-null   int64
#  29  TX近月:前十大淨          5342 non-null   float64
#  30  TX全月:前十大淨          5342 non-null   float64
#  31  TX近月:特定人淨          5342 non-null   float64
#  32  TX全月:特定人淨          5342 non-null   float64
#  33  TX03PM外資(盤後):多方交易  1262 non-null   float64
#  34  TX03PM外資(盤後):空方交易  1262 non-null   float64
#  35  TX03PM外資(盤後):淨額    1262 non-null   float64
# dtypes: datetime64[ns](1), float64(28), int64(7)
# memory usage: 1.5 MB
# None
#              日期  TWA00加權指數:收盤價  TX台指期近期:收盤價  TX2台指期次月:收盤價  TX近期:交割月份  \
# 5459 2026-03-16       33342.51        33250         33373     202603
# 5460 2026-03-17       33836.57        33795         33910     202603
# 5461 2026-03-18       34348.58        34263         34551     202603
# 5462 2026-03-19       33689.68        33553         33655     202604
# 5463 2026-03-20       33543.88        33559         33658     202604
#
#       TX近期:未沖銷契約數  TX2次月:未沖銷契約數  TWX摩根現貨:收盤價  SMTF:收盤價  SMTF2:收盤價  ...  \
# 5459        43657         34633      1466.44       NaN        NaN  ...
# 5460        24545         56655      1488.03       NaN        NaN  ...
# 5461        13354         67799      1511.48       NaN        NaN  ...
# 5462        72389           508      1478.49       NaN        NaN  ...
# 5463        70587           546      1473.15       NaN        NaN  ...
#
#       MTX03外資:空方未平倉  MTX近期:未沖銷契約數  MTX2次月:未沖銷契約數  TX近月:前十大淨  TX全月:前十大淨  \
# 5459         2305.0         28729           9252     -117.0     -934.0
# 5460         1134.0         26900          11196     -837.0     -506.0
# 5461         1368.0         11061          19162       78.0     -602.0
# 5462         2132.0         30913           1919    -1626.0    -1873.0
# 5463          929.0         30355           1851      205.0      123.0
#
#       TX近月:特定人淨  TX全月:特定人淨  TX03PM外資(盤後):多方交易  TX03PM外資(盤後):空方交易  \
# 5459     -844.0    -2010.0            56048.0            55948.0
# 5460     -423.0     -996.0            31594.0            30168.0
# 5461      143.0     -537.0            27266.0            27570.0
# 5462    -1944.0    -4154.0            36278.0            40211.0
# 5463     -377.0     -843.0            55030.0            54091.0
#
#       TX03PM外資(盤後):淨額
# 5459            100.0
# 5460           1426.0
# 5461           -304.0
# 5462          -3933.0
# 5463            939.0
#
# [5 rows x 36 columns]

# %%
import pandas as pd

# 1. 定義標題名稱 (移除原始資料中的「使用者定義」)
# 對應 data4.iloc[:, 2:] 後的 14 個位置
full_columns_data4 = [
    "日期", 
    "外資買賣超", "自營商買賣超", "投信買賣超", "空欄1", 
    "電子外資買賣超", "不含金電外資買賣超", "金融外資買賣超", "空欄2",
    "融資餘額", "融資增減", "券餘", "空欄3", 
    "借券賣出餘額", "空欄4"
]

# 2. 用 iloc 切割：跳過前 4 列參數區，選取第 2 欄之後的所有數據
clean_data4 = data4.iloc[4:, 1:].copy()

# 3. 強制設定標題
# 這裡 clean_data4 應該剛好剩下 14 欄 (37-23=14，或者依原始 df 寬度而定)
clean_data4.columns = full_columns_data4

# 4. 移除那些「使用者定義」產生的空欄位
clean_data4 = clean_data4.drop(columns=["空欄1", "空欄2", "空欄3", "空欄4"])

# 5. 資料型態轉換
clean_data4['日期'] = pd.to_datetime(clean_data4['日期'])

# 將數值欄位轉為 float
cols_to_convert = clean_data4.columns[1:]
clean_data4[cols_to_convert] = clean_data4[cols_to_convert].apply(pd.to_numeric, errors='coerce')

# 6. 重設索引
clean_data4 = clean_data4.dropna(subset=['日期']).reset_index(drop=True)

print("data4 (籌碼面) 清理完成：")
print(clean_data4.tail())
# Out:
# data4 (籌碼面) 清理完成：
#              日期     外資買賣超    自營商買賣超    投信買賣超   電子外資買賣超   不含金電外資買賣超  金融外資買賣超  \
# 5459 2026-03-16 -43825438  -3429648   324837 -39486303   2548482.0 -1733788
# 5460 2026-03-17    472382   9095274   205794   3720166  -1754601.0  -170765
# 5461 2026-03-18   9020754   9963133  -288069   8652699   -413548.0 -1043379
# 5462 2026-03-19 -90947630 -11133581  -346138 -63755994 -10821013.0 -7043443
# 5463 2026-03-20 -40311039 -10104918  1057707 -36148077    908901.0 -1399366
#
#            融資餘額     融資增減      券餘      借券賣出餘額
# 5459  392284076  6837329  223950  15270802.0
# 5460  393467032  1182956  215077  15430595.0
# 5461  399772079  6305047  204948  15506401.0
# 5462  402095986  2323907  193579  15635844.0
# 5463  398591129 -3504857  163036  15787200.0

# %%
import os

# 1. 建立資料夾 (如果不存在就建立)
folder_name = 'data'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    print(f"已建立資料夾: {folder_name}")

# 2. 定義要存檔的 DataFrame 列表與對應檔名
# 假設你之前的變數名稱分別是 clean_df, clean_vix, clean_data3, clean_data4
files_to_save = {
    'market_indices.csv': clean_df,      # 大盤與電子指數
    'vix_index.csv': data_vix_clean,          # 恐慌指數
    'futures_chip.csv': clean_data3,     # 期貨與大額籌碼
    'margin_and_legal.csv': clean_data4  # 融資券與法人買賣超
}

# 3. 迴圈存檔
for file_name, df in files_to_save.items():
    file_path = os.path.join(folder_name, file_name)
    
    # index=False 表示不儲存 Pandas 自動產生的序號列
    # encoding='utf-8-sig' 確保 Excel 打開中文不亂碼
    df.to_csv(file_path, index=False, encoding='utf-8-sig')
    print(f"成功存檔: {file_path} (共 {len(df)} 筆資料)")

print("\n--- 所有資料已準備就緒 ---")
# Out:
# 成功存檔: data\market_indices.csv (共 3966 筆資料)
# 成功存檔: data\vix_index.csv (共 4731 筆資料)
# 成功存檔: data\futures_chip.csv (共 5464 筆資料)
# 成功存檔: data\margin_and_legal.csv (共 5464 筆資料)
#
# --- 所有資料已準備就緒 ---

# %%
df = pd.read_csv('factor_return.csv', encoding='utf-8-sig')

# %%
df  = df.dropna()

# %%
import pandas as pd

# 1. 將百分比字串轉換為小數格式
# 假設除了 '日期' 以外的欄位都是百分比
cols = df.columns.drop('日期')
for col in cols:
    # 去除 % 並轉為浮點數，再除以 100
    df.loc[:, col] = df[col].str.replace('%', '').astype(float) / 100

# 2. 日期處理
df['日期'] = pd.to_datetime(df['日期'])
df = df.sort_values('日期').set_index('日期')

# 3. 將日報酬轉換為「月報酬」
# 使用 (1+r1)*(1+r2)... - 1 的方式計算每月的累積報酬
monthly_df = df.apply(lambda x: (1 + x).resample('M').prod() - 1)

# 4. 計算各因子的 Lag-1 自相關 (Autocorrelation)
# 統計每個月與上個月報酬的相關性
autocorr_results = monthly_df.apply(lambda x: x.autocorr(lag=1))

print("各因子月報酬自相關係數：")
print(autocorr_results)
# Out:
# 各因子月報酬自相關係數：
# 加權指數       0.069491
# 市值前 200    0.047333
# EPS 動能     0.081146
# 高股息        0.104327
# 營收成長       0.084582
# 低 Beta     0.069359
# 利潤率成長     -0.000603
# 價格動能1m     0.035114
# 價格動能3m     0.098342
# 價格動能6m     0.051212
# 低PB        0.086166
# 低PE        0.071349
# dtype: float64
# C:\Users\admin\AppData\Local\Temp\ipykernel_22644\2812890187.py:16: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df.apply(lambda x: (1 + x).resample('M').prod() - 1)
# C:\Users\admin\AppData\Local\Temp\ipykernel_22644\2812890187.py:16: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df.apply(lambda x: (1 + x).resample('M').prod() - 1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
# 忽略所有警告 (建議在開發完成、確認邏輯正確後再使用)
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt

# 解決中文顯示問題 (針對 Windows 系統)
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei'] # 設定字體為微軟正黑體
plt.rcParams['axes.unicode_minus'] = False              # 解決負號 '-' 顯示為亂碼的問題
# 1. 靜態熱力圖
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='RdBu', center=0)
plt.title("Factor Correlation Heatmap")
plt.show()

# 2. 滾動相關係數 (假設視窗為 252 天，即一年)
# 觀察 '低PB' 與 '高股息' 的動態關係
rolling_corr = df['價格動能1m'].rolling(window=252).corr(df['EPS 動能'])

plt.figure(figsize=(12, 6))
rolling_corr.plot()
plt.title("Rolling 1-Year Correlation: Low PB vs High Dividend")
plt.axhline(rolling_corr.mean(), color='r', linestyle='--') # 畫出平均線
plt.show()
